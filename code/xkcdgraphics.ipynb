# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(sin(linspace(0, 10)))
plt.title('Nothing special here.')

# %%
plt.xkcd()
plt.plot(sin(linspace(0, 10)))
plt.title('Woohoo!')
