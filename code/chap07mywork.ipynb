# %%
import brfss
import thinkstats2
import thinkplot

# %%
df = brfss.ReadBrfss(nrows=None)
len(df)
# Out:
# 414509

# %%
sample = thinkstats2.SampleRows(df, 5000)
heights, weights = sample.htm3, sample.wtkg2

# %%
thinkplot.Scatter(heights, weights)
thinkplot.Show(xlabel='Height (cm)',
               ylabel='Weight (kg)',
               axis=[140, 210, 20, 200])

# %%
heights_jitter = thinkstats2.Jitter(heights, 1.3)
weights_jitter = thinkstats2.Jitter(weights, 0.5)

# %%
thinkplot.Scatter(heights_jitter, weights_jitter)
thinkplot.Show(xlabel='Height (cm)',
               ylabel='Weight (kg)',
               axis=[140, 210, 20, 200])

# %%
thinkplot.Scatter(heights_jitter, weights_jitter, alpha=0.1)
thinkplot.Show(xlabel='Height (cm)',
               ylabel='Weight (kg)',
               axis=[140, 210, 20, 200])

# %%
thinkplot.HexBin(heights, weights)

# %%
thinkplot.HexBin(df.htm3, df.wtkg2)
thinkplot.Show(xlabel='Height (cm)',
               ylabel='Weight (kg)',
               axis=[140, 210, 20, 200])

# %%
np.arange(135, 210, 5)
# Out:
# array([135, 140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190, 195,
#        200, 205])

# %%
df_drop = df.dropna(subset=['htm3','wtkg2'])
bins = np.arange(135, 210, 5)
indices = np.digitize(df_drop.htm3, bins)
groups = df_drop.groupby(indices)

# %%
heights = [group.htm3.mean() for i, group in groups]
cdfs = [thinkstats2.Cdf(group.wtkg2) for i, group in groups]

# %%
for percent in [75, 50, 25]:
    weights = [cdf.Percentile(percent) for cdf in cdfs]
    label = '%dth' % percent
    thinkplot.Plot(heights, weights, label=label)
thinkplot.Show(xlabel='height (cm)', ylabel='weight (kg)')

# %%
thinkstats2.Corr(df_drop.htm3, df_drop.wtkg2)
# Out:
# 0.50873647897346397

# %%
thinkstats2.SpearmanCorr(df_drop.htm3, df_drop.wtkg2)
# Out:
# 0.54058462623204762

# %%
thinkstats2.Corr(df_drop.htm3, np.log(df_drop.wtkg2))
# Out:
# 0.53172826059842249
